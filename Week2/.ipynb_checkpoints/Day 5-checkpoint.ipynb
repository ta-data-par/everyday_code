# %%
import numpy as np
import os
import pandas as pd

# %%
os.chdir("../Slides/vehicles/vehicles/")

# %%
os.listdir()
# Out:
# ['.DS_Store',
#  'vehicles.csv',
#  'vehicles.json',
#  'vehicles.xlsx',
#  'vehicles_messy.csv',
#  'vehicles_messy.csv.zip',
#  'vehicles_pipe.txt',
#  'vehicles_tab.txt']

# %%
df=pd.read_csv('vehicles_messy.csv')
# Out:
# C:\Users\eldiy\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3049: DtypeWarning: Columns (70,71,72,73,74,76,79) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 37843 entries, 0 to 37842
# Data columns (total 83 columns):
# barrels08          37843 non-null float64
# barrelsA08         37843 non-null float64
# charge120          37843 non-null float64
# charge240          37843 non-null float64
# city08             37843 non-null int64
# city08U            37843 non-null float64
# cityA08            37843 non-null int64
# cityA08U           37843 non-null float64
# cityCD             37843 non-null float64
# cityE              37843 non-null float64
# cityUF             37843 non-null float64
# co2                37843 non-null int64
# co2A               37843 non-null int64
# co2TailpipeAGpm    37843 non-null float64
# co2TailpipeGpm     37843 non-null float64
# comb08             37843 non-null int64
# comb08U            37843 non-null float64
# combA08            37843 non-null int64
# combA08U           37843 non-null float64
# combE              37843 non-null float64
# combinedCD         37843 non-null float64
# combinedUF         37843 non-null float64
# cylinders          37720 non-null float64
# displ              37723 non-null float64
# drive              36654 non-null object
# engId              37843 non-null int64
# eng_dscr           22440 non-null object
# feScore            37843 non-null int64
# fuelCost08         37843 non-null int64
# fuelCostA08        37843 non-null int64
# fuelType           37843 non-null object
# fuelType1          37843 non-null object
# ghgScore           37843 non-null int64
# ghgScoreA          37843 non-null int64
# highway08          37843 non-null int64
# highway08U         37843 non-null float64
# highwayA08         37843 non-null int64
# highwayA08U        37843 non-null float64
# highwayCD          37843 non-null float64
# highwayE           37843 non-null float64
# highwayUF          37843 non-null float64
# hlv                37843 non-null int64
# hpv                37843 non-null int64
# id                 37843 non-null int64
# lv2                37843 non-null int64
# lv4                37843 non-null int64
# make               37843 non-null object
# model              37843 non-null object
# mpgData            37843 non-null object
# phevBlended        37843 non-null bool
# pv2                37843 non-null int64
# pv4                37843 non-null int64
# range              37843 non-null int64
# rangeCity          37843 non-null float64
# rangeCityA         37843 non-null float64
# rangeHwy           37843 non-null float64
# rangeHwyA          37843 non-null float64
# trany              37832 non-null object
# UCity              37843 non-null float64
# UCityA             37843 non-null float64
# UHighway           37843 non-null float64
# UHighwayA          37843 non-null float64
# VClass             37843 non-null object
# year               37843 non-null int64
# youSaveSpend       37843 non-null int64
# guzzler            2281 non-null object
# trans_dscr         15047 non-null object
# tCharger           5186 non-null object
# sCharger           666 non-null object
# atvType            3072 non-null object
# fuelType2          1408 non-null object
# rangeA             1403 non-null object
# evMotor            562 non-null object
# mfrCode            7025 non-null object
# c240Dscr           37 non-null object
# charge240b         37843 non-null float64
# c240bDscr          36 non-null object
# createdOn          37843 non-null object
# modifiedOn         37843 non-null object
# startStop          6138 non-null object
# phevCity           37843 non-null int64
# phevHwy            37843 non-null int64
# phevComb           37843 non-null int64
# dtypes: bool(1), float64(32), int64(27), object(23)
# memory usage: 23.7+ MB

# %%
df.shape
# Out:
# (37843, 83)

# %%
df.describe()
# Out:
#           barrels08    barrelsA08  charge120     charge240        city08  \
# count  37843.000000  37843.000000    37843.0  37843.000000  37843.000000
# mean      17.532506      0.216169        0.0      0.023531     17.941389
# std        4.575950      1.141527        0.0      0.427647      6.660360
# min        0.060000      0.000000        0.0      0.000000      6.000000
# 25%       14.330870      0.000000        0.0      0.000000     15.000000
# 50%       17.347895      0.000000        0.0      0.000000     17.000000
# 75%       20.600625      0.000000        0.0      0.000000     20.000000
# max       47.087143     18.311667        0.0     12.000000    138.000000
#
#             city08U       cityA08      cityA08U        cityCD         cityE  \
# count  37843.000000  37843.000000  37843.000000  37843.000000  37843.000000
# mean       4.042737      0.520149      0.327163      0.000406      0.184790
# std        9.645820      3.837874      3.542596      0.039918      2.904558
# min        0.000000      0.000000      0.000000      0.000000      0.000000
# 25%        0.000000      0.000000      0.000000      0.000000      0.000000
# 50%        0.000000      0.000000      0.000000      0.000000      0.000000
# 75%        0.000000      0.000000      0.000000      0.000000      0.000000
# max      138.304000    127.000000    127.093000      5.350000    122.000000
#
#        ...         UCity        UCityA      UHighway     UHighwayA  \
# count  ...  37843.000000  37843.000000  37843.000000  37843.000000
# mean   ...     22.587229      0.652380     33.619221      0.933845
# std    ...      9.350163      5.284547     10.048326      6.059456
# min    ...      0.000000      0.000000      0.000000      0.000000
# 25%    ...     18.000000      0.000000     27.100000      0.000000
# 50%    ...     21.000000      0.000000     33.000000      0.000000
# 75%    ...     25.139300      0.000000     38.109600      0.000000
# max    ...    197.577100    181.560900    159.100000    152.187800
#
#                year  youSaveSpend    charge240b      phevCity       phevHwy  \
# count  37843.000000  37843.000000  37843.000000  37843.000000  37843.000000
# mean    2000.064398  -2658.999022      0.004360      0.069313      0.068203
# std       10.390588   2553.098329      0.142776      1.966806      1.871986
# min     1984.000000 -22250.000000      0.000000      0.000000      0.000000
# 25%     1990.000000  -4250.000000      0.000000      0.000000      0.000000
# 50%     2001.000000  -2500.000000      0.000000      0.000000      0.000000
# 75%     2009.000000   -750.000000      0.000000      0.000000      0.000000
# max     2017.000000   4000.000000      7.000000     97.000000     79.000000
#
#            phevComb
# count  37843.000000
# mean       0.068573
# std        1.913647
# min        0.000000
# 25%        0.000000
# 50%        0.000000
# 75%        0.000000
# max       88.000000
#
# [8 rows x 59 columns]

# %% [markdown]
# # Missing values

# %%
from IPython.display import Image
Image(filename='C:/Users/eldiy/Documents/Ironhack/Slides/missing.png')

# %%
df.columns
# Out:
# Index(['barrels08', 'barrelsA08', 'charge120', 'charge240', 'city08',
#        'city08U', 'cityA08', 'cityA08U', 'cityCD', 'cityE', 'cityUF', 'co2',
#        'co2A', 'co2TailpipeAGpm', 'co2TailpipeGpm', 'comb08', 'comb08U',
#        'combA08', 'combA08U', 'combE', 'combinedCD', 'combinedUF', 'cylinders',
#        'displ', 'drive', 'engId', 'eng_dscr', 'feScore', 'fuelCost08',
#        'fuelCostA08', 'fuelType', 'fuelType1', 'ghgScore', 'ghgScoreA',
#        'highway08', 'highway08U', 'highwayA08', 'highwayA08U', 'highwayCD',
#        'highwayE', 'highwayUF', 'hlv', 'hpv', 'id', 'lv2', 'lv4', 'make',
#        'model', 'mpgData', 'phevBlended', 'pv2', 'pv4', 'range', 'rangeCity',
#        'rangeCityA', 'rangeHwy', 'rangeHwyA', 'trany', 'UCity', 'UCityA',
#        'UHighway', 'UHighwayA', 'VClass', 'year', 'youSaveSpend', 'guzzler',
#        'trans_dscr', 'tCharger', 'sCharger', 'atvType', 'fuelType2', 'rangeA',
#        'evMotor', 'mfrCode', 'c240Dscr', 'charge240b', 'c240bDscr',
#        'createdOn', 'modifiedOn', 'startStop', 'phevCity', 'phevHwy',
#        'phevComb'],
#       dtype='object')

# %%
# %matplotlib inline
df.trany.value_counts().plot.bar()

# %%
df.trany.value_counts()/df.shape[0]
# Out:
# Automatic 4-spd                     0.291784
# Manual 5-spd                        0.219618
# Automatic 3-spd                     0.083265
# Automatic (S6)                      0.069709
# Manual 6-spd                        0.064186
# Automatic 5-spd                     0.057712
# Manual 4-spd                        0.039188
# Automatic 6-spd                     0.037841
# Automatic (S8)                      0.025368
# Automatic (S5)                      0.021774
# Automatic (variable gear ratios)    0.017995
# Automatic 7-spd                     0.017520
# Automatic (S7)                      0.006897
# Auto(AM-S7)                         0.006765
# Automatic 8-spd                     0.006421
# Automatic (S4)                      0.006157
# Auto(AM7)                           0.004228
# Auto(AV-S6)                         0.003832
# Auto(AM6)                           0.002907
# Automatic (A1)                      0.002880
# Auto(AM-S6)                         0.002431
# Automatic 9-spd                     0.002378
# Manual 3-spd                        0.002035
# Manual 7-spd                        0.001797
# Auto(AV-S7)                         0.001665
# Automatic (S9)                      0.000687
# Auto(AV-S8)                         0.000687
# Manual 4-spd Doubled                0.000449
# Auto(AM5)                           0.000317
# Automatic (AV-S6)                   0.000238
# Auto(AM-S8)                         0.000159
# Auto(AM8)                           0.000132
# Automatic (A6)                      0.000106
# Automatic (AV)                      0.000106
# Manual(M7)                          0.000079
# Auto (AV)                           0.000053
# Automatic (AM5)                     0.000053
# Auto(L3)                            0.000053
# Auto(L4)                            0.000053
# Manual 5 spd                        0.000026
# Automatic 6spd                      0.000026
# Auto (AV-S8)                        0.000026
# Auto(A1)                            0.000026
# Automatic (AM6)                     0.000026
# Auto (AV-S6)                        0.000026
# Auto(AM-S9)                         0.000026
# Name: trany, dtype: float64

# %%
df.phevCity.value_counts().plot.bar()

# %%
data=pd.read_csv('vehicles.csv')

# %%
df.columns[df.isnull().sum()>0]
# Out:
# Index(['cylinders', 'displ', 'drive', 'eng_dscr', 'trany', 'guzzler',
#        'trans_dscr', 'tCharger', 'sCharger', 'atvType', 'fuelType2', 'rangeA',
#        'evMotor', 'mfrCode', 'c240Dscr', 'c240bDscr', 'startStop'],
#       dtype='object')

# %%
null_cols=df.isnull().sum()
drop_percentage=round(null_cols[null_cols>0]/df.shape[0]*100,2)
drop_cols=drop_percentage[drop_percentage>75].index
drop_cols
# Out:
# Index(['guzzler', 'tCharger', 'sCharger', 'atvType', 'fuelType2', 'rangeA',
#        'evMotor', 'mfrCode', 'c240Dscr', 'c240bDscr', 'startStop'],
#       dtype='object')

# %%
df[drop_cols].describe()
# Out:
#        guzzler tCharger sCharger atvType fuelType2 rangeA     evMotor mfrCode  \
# count     2281     5186      666    3072      1408   1403         562    7025
# unique       3        1        1       8         4    157         110      45
# top          G        T        S     FFV       E85    310  288V Ni-MH     GMX
# freq      1302     5186      666    1325      1325    117         114    1061
#
#                 c240Dscr            c240bDscr startStop
# count                 37                   36      6138
# unique                 5                    4         2
# top     standard charger  80 amp dual charger         N
# freq                  28                   28      4462

# %%
df.shape
# Out:
# (37843, 83)

# %%
df=df.drop(drop_cols,axis=1)
df.shape
# Out:
# (37843, 72)

# %%
null_cols=df.isnull().sum()
drop_percentage=round(null_cols[null_cols>0]/df.shape[0]*100,2)
"""drop_cols=drop_percentage[drop_percentage>75].index
drop_cols"""
drop_percentage
# Out:
# cylinders      0.33
# displ          0.32
# drive          3.14
# eng_dscr      40.70
# trany          0.03
# trans_dscr    60.24
# dtype: float64

# %%
drop_cols2=drop_percentage.index
drop_cols2
# Out:
# Index([], dtype='object')

# %%
df[drop_cols2]=df[drop_cols2].fillna(0)
null_cols=df.isnull().sum()
drop_percentage=round(null_cols[null_cols>0]/df.shape[0]*100,2)
drop_percentage
# Out:
# cylinders    0.33
# displ        0.32
# drive        3.14
# trany        0.03
# dtype: float64

# %%
drop_cols3=drop_percentage.index
df[drop_cols3]=df[drop_cols3].interpolate(method='linear',order=1)
null_cols=df.isnull().sum()
drop_percentage=round(null_cols[null_cols>0]/df.shape[0]*100,2)
drop_percentage
# Out:
# drive    3.14
# trany    0.03
# dtype: float64

# %%
a=np.random.random((3,4))
a[2,2]=np.nan
a
# Out:
# array([[0.37241144, 0.5432275 , 0.22449272, 0.8748173 ],
#        [0.11740295, 0.48663006, 0.60466462, 0.35323585],
#        [0.73254189, 0.28134125,        nan, 0.13334744]])

# %%
a1=pd.DataFrame(a).T
a1.interpolate(method='linear')
# Out:
#           0         1         2
# 0  0.372411  0.117403  0.732542
# 1  0.543227  0.486630  0.281341
# 2  0.224493  0.604665  0.207344
# 3  0.874817  0.353236  0.133347

# %%
drop_cols3=drop_percentage.index
df[drop_cols3]=df[drop_cols3].interpolate(method='linear',order=1)
null_cols=df.isnull().sum()
drop_percentage=round(null_cols[null_cols>0]/df.shape[0]*100,2)
drop_percentage
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-60-12b8ba4df820> in <module>
#       1 drop_cols3=drop_percentage.index
# ----> 2 df[drop_cols3]=df[drop_cols3].interpolate(method='linear',order=1)
#       3 null_cols=df.isnull().sum()
#       4 drop_percentage=round(null_cols[null_cols>0]/df.shape[0]*100,2)
#       5 drop_percentage
#
# ~\Anaconda3\lib\site-packages\pandas\core\generic.py in interpolate(self, method, axis, limit, inplace, limit_direction, limit_area, downcast, **kwargs)
#    6812         if _maybe_transposed_self._data.get_dtype_counts().get(
#    6813                 'object') == len(_maybe_transposed_self.T):
# -> 6814             raise TypeError("Cannot interpolate with all object-dtype columns "
#    6815                             "in the DataFrame. Try setting at least one "
#    6816                             "column to a numeric dtype.")
#
# TypeError: Cannot interpolate with all object-dtype columns in the DataFrame. Try setting at least one column to a numeric dtype.

# %% [markdown]
# # Incorrect values

# %%
null_cols=df.isnull().sum()
drop_percentage=round(null_cols[null_cols>0]/df.shape[0]*100,2)
drop_cols2=drop_percentage.index
df[drop_cols2]=df[drop_cols2].fillna(0)
null_cols=df.isnull().sum()
drop_percentage=round(null_cols[null_cols>0]/df.shape[0]*100,2)
drop_percentage
# Out:
# Series([], dtype: float64)

# %%
test=df[(df.cylinders==0)&(df.displ!=0)]
test[['year','make','model','trany','drive','fuelType','cylinders','displ']]
# Out:
# Empty DataFrame
# Columns: [year, make, model, trany, drive, fuelType, cylinders, displ]
# Index: []

# %%
df.loc[(df.cylinders==0)&(df.displ!=0),'cylinders']=4

# %% [markdown]
# # Low Variance

# %%
low_variance=[]
for col in df. ():
    minimum=min(df[col])
    ninety_perc=np.percentile(df[col],90)
    if ninety_perc==minimum:
        low_variance.append(col)
    maximum=max(df[col])
    tenth_perc=np.percentile(df[col],10)
    if tenth_perc==maximum:
        low_variance.append(col)
    
print(low_variance)
# Out:
# ['barrelsA08', 'charge120', 'charge120', 'charge240', 'cityA08', 'cityA08U', 'cityCD', 'cityE', 'cityUF', 'co2A', 'co2TailpipeAGpm', 'combA08', 'combA08U', 'combE', 'combinedCD', 'combinedUF', 'fuelCostA08', 'ghgScoreA', 'highwayA08', 'highwayA08U', 'highwayCD', 'highwayE', 'highwayUF', 'phevBlended', 'range', 'rangeCity', 'rangeCityA', 'rangeHwy', 'rangeHwyA', 'UCityA', 'UHighwayA', 'charge240b', 'phevCity', 'phevHwy', 'phevComb']

# %%
len(low_variance)
# Out:
# 34

# %%
len(low_variance)
# Out:
# 35

# %%
#df=df.drop(low_variance,axis=1)
df.shape
# Out:
# (37843, 38)

# %% [markdown]
# # Outliers

# %%
df.boxplot(column='cylinders')

# %%
df_desc=df.describe().T
df_desc['IQR']=df_desc['75%']-df_desc['25%']
df_desc
# Out:
#                   count          mean           std       min         25%  \
# barrels08       37843.0     17.532506      4.575950      0.06    14.33087
# city08          37843.0     17.941389      6.660360      6.00    15.00000
# city08U         37843.0      4.042737      9.645820      0.00     0.00000
# co2             37843.0     61.503713    153.387715     -1.00    -1.00000
# co2TailpipeGpm  37843.0    473.179736    122.188847      0.00   388.00000
# comb08          37843.0     20.195809      6.623444      7.00    17.00000
# comb08U         37843.0      4.549751     10.389994      0.00     0.00000
# cylinders       37843.0      5.719446      1.778959      0.00     4.00000
# displ           37843.0      3.307658      1.371982      0.00     2.20000
# engId           37843.0   8860.308961  17829.683477      0.00     0.00000
# feScore         37843.0     -0.035145      2.379584     -1.00    -1.00000
# fuelCost08      37843.0   1882.060090    510.280408    550.00  1500.00000
# ghgScore        37843.0     -0.037206      2.374338     -1.00    -1.00000
# highway08       37843.0     24.104881      6.963192      9.00    20.00000
# highway08U      37843.0      5.438467     11.936327      0.00     0.00000
# hlv             37843.0      2.026214      5.947989      0.00     0.00000
# hpv             37843.0     10.424332     28.148770      0.00     0.00000
# id              37843.0  19019.286235  11034.784855      1.00  9461.50000
# lv2             37843.0      1.849219      4.429983      0.00     0.00000
# lv4             37843.0      6.165658      9.743297      0.00     0.00000
# pv2             37843.0     13.696113     31.269930      0.00     0.00000
# pv4             37843.0     33.769125     45.914462      0.00     0.00000
# UCity           37843.0     22.587229      9.350163      0.00    18.00000
# UHighway        37843.0     33.619221     10.048326      0.00    27.10000
# year            37843.0   2000.064398     10.390588   1984.00  1990.00000
# youSaveSpend    37843.0  -2658.999022   2553.098329 -22250.00 -4250.00000
#
#                          50%           75%           max           IQR
# barrels08          17.347895     20.600625     47.087143      6.269755
# city08             17.000000     20.000000    138.000000      5.000000
# city08U             0.000000      0.000000    138.304000      0.000000
# co2                -1.000000     -1.000000    847.000000      0.000000
# co2TailpipeGpm    467.736842    555.437500   1269.571429    167.437500
# comb08             19.000000     23.000000    124.000000      6.000000
# comb08U             0.000000      0.000000    124.360100      0.000000
# cylinders           6.000000      6.000000     16.000000      2.000000
# displ               3.000000      4.300000      8.400000      2.100000
# engId             211.000000   4505.000000  69102.000000   4505.000000
# feScore            -1.000000     -1.000000     10.000000      0.000000
# fuelCost08       1850.000000   2200.000000   5800.000000    700.000000
# ghgScore           -1.000000     -1.000000     10.000000      0.000000
# highway08          24.000000     27.000000    111.000000      7.000000
# highway08U          0.000000      0.000000    111.370000      0.000000
# hlv                 0.000000      0.000000     49.000000      0.000000
# hpv                 0.000000      0.000000    195.000000      0.000000
# id              18923.000000  28570.500000  38173.000000  19109.000000
# lv2                 0.000000      0.000000     41.000000      0.000000
# lv4                 0.000000     13.000000     55.000000     13.000000
# pv2                 0.000000      0.000000    194.000000      0.000000
# pv4                 0.000000     91.000000    192.000000     91.000000
# UCity              21.000000     25.139300    197.577100      7.139300
# UHighway           33.000000     38.109600    159.100000     11.009600
# year             2001.000000   2009.000000   2017.000000     19.000000
# youSaveSpend    -2500.000000   -750.000000   4000.000000   3500.000000

# %%
outliers=pd.DataFrame(columns=df.columns)

for col in df_desc.index:
    iqr=df_desc.at[col,'IQR']
    cutoff=iqr*1.5
    lower=df_desc.at[col,'25%']-cutoff
    upper=df_desc.at[col,'75%']+cutoff
    results=df[(df[col]<lower)|(df[col]>upper)].copy()
    results['Outlier']=col
    outliers=outliers.append(results)
outliers
# Out:
# C:\Users\eldiy\Anaconda3\lib\site-packages\pandas\core\frame.py:6692: FutureWarning: Sorting because non-concatenation axis is not aligned. A future version
# of pandas will change to not sort by default.
#
# To accept the future behavior, pass 'sort=False'.
#
# To retain the current behavior and silence the warning, pass 'sort=True'.
#
#   sort=sort)
#             Outlier    UCity  UHighway                       VClass  \
# 47        barrels08  11.0000   15.0000                         Vans
# 58        barrels08  12.0000   15.0000                         Vans
# 69        barrels08  12.0000   15.0000                         Vans
# 80        barrels08  11.0000   14.0000                         Vans
# 275       barrels08  11.0000   16.0000       Standard Pickup Trucks
# 642       barrels08  11.0000   15.0000     Special Purpose Vehicles
# 686       barrels08  12.2222   14.0000     Special Purpose Vehicles
# 1035      barrels08  10.0000   16.0000  Special Purpose Vehicle 4WD
# 1768      barrels08  11.0000   15.0000  Special Purpose Vehicle 2WD
# 1770      barrels08   8.8889   14.0000                  Two Seaters
# 1778      barrels08  10.0000   18.0000                  Two Seaters
# 1781      barrels08  10.0000   18.0000                  Two Seaters
# 1979      barrels08   9.0000   12.8205              Subcompact Cars
# 1990      barrels08   9.0000   12.8205              Subcompact Cars
# 2002      barrels08   9.0000   13.0000              Subcompact Cars
# 2807      barrels08  10.0000   18.0000                  Two Seaters
# 2817      barrels08   8.8889   16.6667                  Two Seaters
# 3208      barrels08  19.0000   33.0000                   Large Cars
# 3629      barrels08  10.0000   18.0000                  Two Seaters
# 3641      barrels08  10.0000   16.6667                  Two Seaters
# 3706      barrels08  10.0000   19.0000              Subcompact Cars
# 4036      barrels08  19.0000   32.0513                   Large Cars
# 4443      barrels08  10.1000   18.9000                  Two Seaters
# 4449      barrels08  10.9000   17.3000                  Two Seaters
# 4544      barrels08  30.8000   43.8000              Subcompact Cars
# 5006      barrels08  12.0000   19.0000   Standard Pickup Trucks 2WD
# 5110      barrels08  12.2222   18.0000             Vans, Cargo Type
# 5336      barrels08  10.0000   18.0000                  Two Seaters
# 5339      barrels08  10.9000   17.3000                  Two Seaters
# 5765      barrels08  15.9000   26.1000                   Large Cars
# ...             ...      ...       ...                          ...
# 36455  youSaveSpend  10.0000   16.0000       Standard Pickup Trucks
# 36498  youSaveSpend  11.1111   18.0000              Subcompact Cars
# 36500  youSaveSpend  11.1111   18.0000              Subcompact Cars
# 36511  youSaveSpend  10.0000   16.0000       Standard Pickup Trucks
# 36617  youSaveSpend  12.2222   18.0000                 Compact Cars
# 36618  youSaveSpend  12.2222   18.0000                 Compact Cars
# 36666  youSaveSpend  12.0000   15.0000       Standard Pickup Trucks
# 36774  youSaveSpend  12.2222   18.0000                 Midsize Cars
# 36775  youSaveSpend  12.2222   18.0000                 Midsize Cars
# 36776  youSaveSpend  12.2222   18.0000                 Midsize Cars
# 36777  youSaveSpend  12.2222   18.0000                 Midsize Cars
# 36810  youSaveSpend  11.1111   18.0000                 Midsize Cars
# 36812  youSaveSpend  12.0000   20.0000                 Midsize Cars
# 36813  youSaveSpend  11.1111   18.0000                 Midsize Cars
# 36855  youSaveSpend  12.0000   19.0000                   Large Cars
# 36999  youSaveSpend  11.0000   16.0000       Standard Pickup Trucks
# 37131  youSaveSpend  10.0000   17.0000       Standard Pickup Trucks
# 37137  youSaveSpend  10.0000   17.0000       Standard Pickup Trucks
# 37250  youSaveSpend  11.0000   16.0000                         Vans
# 37300  youSaveSpend  11.1111   15.0000                         Vans
# 37356  youSaveSpend  10.0000   16.6667     Special Purpose Vehicles
# 37431  youSaveSpend  12.2222   14.0000     Special Purpose Vehicles
# 37448  youSaveSpend  12.0000   20.0000                  Two Seaters
# 37458  youSaveSpend  13.0000   19.2308                  Two Seaters
# 37459  youSaveSpend  10.0000   18.0000                  Two Seaters
# 37475  youSaveSpend   8.0000   14.0000                  Two Seaters
# 37615  youSaveSpend  13.0000   20.0000              Subcompact Cars
# 37672  youSaveSpend  11.1111   18.0000              Subcompact Cars
# 37673  youSaveSpend  11.1111   18.0000              Subcompact Cars
# 37827  youSaveSpend  12.0000   20.0000                 Compact Cars
#
#        barrels08 city08  city08U co2  co2TailpipeGpm comb08  ...  \
# 47     32.961000      9      0.0  -1      888.700000     10  ...
# 58     32.961000     10      0.0  -1      888.700000     10  ...
# 69     32.961000     10      0.0  -1      888.700000     10  ...
# 80     32.961000      9      0.0  -1      888.700000     10  ...
# 275    32.961000      9      0.0  -1      888.700000     10  ...
# 642    32.961000      9      0.0  -1      888.700000     10  ...
# 686    32.961000     10      0.0  -1      888.700000     10  ...
# 1035   32.961000      8      0.0  -1      888.700000     10  ...
# 1768   32.961000      9      0.0  -1      888.700000     10  ...
# 1770   41.201250      7      0.0  -1     1110.875000      8  ...
# 1778   32.961000      8      0.0  -1      888.700000     10  ...
# 1781   32.961000      8      0.0  -1      888.700000     10  ...
# 1979   41.201250      7      0.0  -1     1110.875000      8  ...
# 1990   41.201250      7      0.0  -1     1110.875000      8  ...
# 2002   41.201250      7      0.0  -1     1110.875000      8  ...
# 2807   32.961000      8      0.0  -1      888.700000     10  ...
# 2817   36.623333      7      0.0  -1      987.444444      9  ...
# 3208    0.103333     15      0.0  -1      393.862500     18  ...
# 3629   32.961000      8      0.0  -1      888.700000     10  ...
# 3641   36.623333      8      0.0  -1      987.444444      9  ...
# 3706   32.961000      8      0.0  -1      888.700000     10  ...
# 4036    0.103333     15      0.0  -1      393.862500     18  ...
# 4443   32.961000      8      0.0  -1      888.700000     10  ...
# 4449   32.961000      9      0.0  -1      888.700000     10  ...
# 4544    0.068889     24      0.0  -1      262.575000     27  ...
# 5006    0.169091     10      0.0  -1      644.502273     11  ...
# 5110    0.169091     10      0.0  -1      644.502273     11  ...
# 5336   32.961000      8      0.0  -1      888.700000     10  ...
# 5339   32.961000      9      0.0  -1      888.700000     10  ...
# 5765    0.124000     13      0.0  -1      472.635000     15  ...
# ...          ...    ...      ...  ..             ...    ...  ...
# 36455  32.961000      8      0.0  -1      888.700000     10  ...
# 36498  29.964545      9      0.0  -1      807.909091     11  ...
# 36500  29.964545      9      0.0  -1      807.909091     11  ...
# 36511  32.961000      8      0.0  -1      888.700000     10  ...
# 36617  29.964545     10      0.0  -1      807.909091     11  ...
# 36618  29.964545     10      0.0  -1      807.909091     11  ...
# 36666  32.961000     10      0.0  -1      888.700000     10  ...
# 36774  29.964545     10      0.0  -1      807.909091     11  ...
# 36775  29.964545     10      0.0  -1      807.909091     11  ...
# 36776  29.964545     10      0.0  -1      807.909091     11  ...
# 36777  29.964545     10      0.0  -1      807.909091     11  ...
# 36810  29.964545      9      0.0  -1      807.909091     11  ...
# 36812  29.964545     10      0.0  -1      807.909091     11  ...
# 36813  29.964545      9      0.0  -1      807.909091     11  ...
# 36855  27.467500     10      0.0  -1      740.583333     12  ...
# 36999  32.961000      9      0.0  -1      888.700000     10  ...
# 37131  32.961000      8      0.0  -1      888.700000     10  ...
# 37137  32.961000      8      0.0  -1      888.700000     10  ...
# 37250  32.961000      9      0.0  -1      888.700000     10  ...
# 37300  32.961000      9      0.0  -1      888.700000     10  ...
# 37356  32.961000      8      0.0  -1      888.700000     10  ...
# 37431  32.961000     10      0.0  -1      888.700000     10  ...
# 37448  29.964545     10      0.0  -1      807.909091     11  ...
# 37458  27.467500     11      0.0  -1      740.583333     12  ...
# 37459  32.961000      8      0.0  -1      888.700000     10  ...
# 37475  41.201250      7      0.0  -1     1110.875000      8  ...
# 37615  27.467500     11      0.0  -1      740.583333     12  ...
# 37672  29.964545      9      0.0  -1      807.909091     11  ...
# 37673  29.964545      9      0.0  -1      807.909091     11  ...
# 37827  29.964545     10      0.0  -1      807.909091     11  ...
#
#                 make                         model  \
# 47             Dodge           B150/B250 Wagon 2WD
# 58             Dodge                B350 Wagon 2WD
# 69             Dodge                B350 Wagon 2WD
# 80             Dodge                B350 Wagon 2WD
# 275        Chevrolet              C1500 Pickup 2WD
# 642       Land Rover                  Defender 110
# 686           Toyota               Cab/Chassis 2WD
# 1035           Dodge    AW100/AW150 Ramcharger 4WD
# 1768           Dodge          D250 Cab Chassis 2WD
# 1770         Ferrari                   Ferrari F50
# 1778     Lamborghini                  DB132/Diablo
# 1781     Lamborghini                  DB132/Diablo
# 1979    Aston Martin                       Lagonda
# 1990    Aston Martin        Saloon/Vantage/Volante
# 2002    Aston Martin        Saloon/Vantage/Volante
# 2807     Lamborghini                  DB132/Diablo
# 2817          Vector               Avtech SC / M12
# 3208            Ford            Crown Victoria CNG
# 3629     Lamborghini            DB132/144 - Diablo
# 3641          Vector               Avtech SC / M12
# 3706         Ferrari                   Ferrari 456
# 4036            Ford            Crown Victoria CNG
# 4443         Ferrari         Ferrari 550 Maranello
# 4449     Lamborghini              DB132/144 Diablo
# 4544           Honda                     Civic CNG
# 5006            Ford           F250 Pickup 2WD CNG
# 5110            Ford        E250 Econoline 2WD CNG
# 5336         Ferrari                 550 Maranello
# 5339     Lamborghini              DB132/144 Diablo
# 5765            Ford            Crown Victoria CNG
# ...              ...                           ...
# 36455          Dodge          W100/W150 Pickup 4WD
# 36498    Rolls-Royce                   Continental
# 36500    Rolls-Royce                   Corniche IV
# 36511          Dodge               W250 Pickup 4WD
# 36617  Mercedes-Benz                        500SEC
# 36618  Mercedes-Benz                        560SEC
# 36666           Ford               F250 Pickup 4WD
# 36774  Mercedes-Benz                         500SE
# 36775  Mercedes-Benz                   500SEL 5.6L
# 36776  Mercedes-Benz                         560SE
# 36777  Mercedes-Benz                        560SEL
# 36810    Rolls-Royce        Eight/Mulsanne S and S
# 36812    Rolls-Royce          Turbo R/Turbo R(lwb)
# 36813    Rolls-Royce  Silver Spirit II/Silver Spur
# 36855  Mercedes-Benz                        600SEL
# 36999      Chevrolet              C1500 Pickup 2WD
# 37131          Dodge          W100/W150 Pickup 4WD
# 37137          Dodge               W250 Pickup 4WD
# 37250          Dodge                B350 Wagon 2WD
# 37300          Dodge                  B350 Van 2WD
# 37356          Dodge                Ramcharger 4WD
# 37431         Toyota               Cab/Chassis 2WD
# 37448        Ferrari                Ferrari 512 TR
# 37458         Jaguar               XJRS Convertble
# 37459    Lamborghini                  DB132/Diablo
# 37475         Vector                            W8
# 37615         Jaguar                    XJRS Coupe
# 37672    Rolls-Royce                   Continental
# 37673    Rolls-Royce                   Corniche IV
# 37827    Rolls-Royce                 Continental R
#
#                          modifiedOn  mpgData pv2  pv4   trans_dscr  \
# 47     Tue Jan 01 00:00:00 EST 2013        N   0    0            0
# 58     Tue Jan 01 00:00:00 EST 2013        N   0    0            0
# 69     Tue Jan 01 00:00:00 EST 2013        N   0    0            0
# 80     Tue Jan 01 00:00:00 EST 2013        N   0    0            0
# 275    Tue Jan 01 00:00:00 EST 2013        N   0    0        CLKUP
# 642    Tue Jan 01 00:00:00 EST 2013        N   0    0            0
# 686    Tue Jan 01 00:00:00 EST 2013        N   0    0  2MODE 2LKUP
# 1035   Tue Jan 01 00:00:00 EST 2013        N   0    0      Creeper
# 1768   Tue Jan 01 00:00:00 EST 2013        N   0    0            0
# 1770   Tue Jan 01 00:00:00 EST 2013        N   0    0            0
# 1778   Tue Jan 01 00:00:00 EST 2013        N   0    0            0
# 1781   Tue Jan 01 00:00:00 EST 2013        N   0    0            0
# 1979   Tue Jan 01 00:00:00 EST 2013        N   0   87            0
# 1990   Tue Jan 01 00:00:00 EST 2013        N   0   79            0
# 2002   Tue Jan 01 00:00:00 EST 2013        N   0   79            0
# 2807   Tue Jan 01 00:00:00 EST 2013        Y   0    0            0
# 2817   Tue Jan 01 00:00:00 EST 2013        N   0    0            0
# 3208   Tue Jan 01 00:00:00 EST 2013        N   0  111        CLKUP
# 3629   Tue Jan 01 00:00:00 EST 2013        N   0    0            0
# 3641   Tue Jan 01 00:00:00 EST 2013        N   0    0            0
# 3706   Tue Jan 01 00:00:00 EST 2013        N  87    0        CLKUP
# 4036   Tue Jan 01 00:00:00 EST 2013        N   0  111        CLKUP
# 4443   Tue Jan 01 00:00:00 EST 2013        N   0    0            0
# 4449   Tue Jan 01 00:00:00 EST 2013        N   0    0            0
# 4544   Tue Jan 01 00:00:00 EST 2013        Y  85   90        CLKUP
# 5006   Tue Jan 01 00:00:00 EST 2013        N   0    0        CLKUP
# 5110   Tue Jan 01 00:00:00 EST 2013        N   0    0        CLKUP
# 5336   Tue Jan 01 00:00:00 EST 2013        N   0    0            0
# 5339   Tue Jan 01 00:00:00 EST 2013        N   0    0            0
# 5765   Tue Jan 01 00:00:00 EST 2013        Y   0  111        CLKUP
# ...                             ...      ...  ..  ...          ...
# 36455  Tue Jan 01 00:00:00 EST 2013        N   0    0      Creeper
# 36498  Tue Jan 01 00:00:00 EST 2013        N  82    0        3MODE
# 36500  Tue Jan 01 00:00:00 EST 2013        N  82    0        3MODE
# 36511  Tue Jan 01 00:00:00 EST 2013        N   0    0      Creeper
# 36617  Tue Jan 01 00:00:00 EST 2013        N   0   86            0
# 36618  Tue Jan 01 00:00:00 EST 2013        N   0   86            0
# 36666  Tue Jan 01 00:00:00 EST 2013        N   0    0      Creeper
# 36774  Tue Jan 01 00:00:00 EST 2013        N   0   91            0
# 36775  Tue Jan 01 00:00:00 EST 2013        N   0   98            0
# 36776  Tue Jan 01 00:00:00 EST 2013        N   0   91            0
# 36777  Tue Jan 01 00:00:00 EST 2013        N   0   98            0
# 36810  Tue Jan 01 00:00:00 EST 2013        N   0   98        3MODE
# 36812  Tue Jan 01 00:00:00 EST 2013        N   0   98        4MODE
# 36813  Tue Jan 01 00:00:00 EST 2013        N   0   98        3MODE
# 36855  Tue Jan 01 00:00:00 EST 2013        N   0  112            0
# 36999  Tue Jan 01 00:00:00 EST 2013        N   0    0        CLKUP
# 37131  Tue Jan 01 00:00:00 EST 2013        N   0    0      Creeper
# 37137  Tue Jan 01 00:00:00 EST 2013        N   0    0      Creeper
# 37250  Tue Jan 01 00:00:00 EST 2013        N   0    0            0
# 37300  Tue Jan 01 00:00:00 EST 2013        N   0    0            0
# 37356  Tue Jan 01 00:00:00 EST 2013        N   0    0      Creeper
# 37431  Tue Jan 01 00:00:00 EST 2013        N   0    0  2MODE 2LKUP
# 37448  Tue Jan 01 00:00:00 EST 2013        N   0    0            0
# 37458  Tue Jan 01 00:00:00 EST 2013        N   0    0    EMS 3MODE
# 37459  Tue Jan 01 00:00:00 EST 2013        N   0    0            0
# 37475  Tue Jan 01 00:00:00 EST 2013        N   0    0          EMS
# 37615  Tue Jan 01 00:00:00 EST 2013        N  77    0            0
# 37672  Tue Jan 01 00:00:00 EST 2013        N  82    0        3MODE
# 37673  Tue Jan 01 00:00:00 EST 2013        N  82    0        3MODE
# 37827  Tue Jan 01 00:00:00 EST 2013        N  89    0        4MODE
#
#                  trany  year youSaveSpend
# 47     Automatic 3-spd  1985       -10000
# 58     Automatic 3-spd  1985       -10000
# 69     Automatic 3-spd  1985       -10000
# 80     Automatic 3-spd  1985       -10000
# 275    Automatic 4-spd  1993       -10000
# 642       Manual 5-spd  1993       -13500
# 686    Automatic 4-spd  1993       -10000
# 1035      Manual 4-spd  1985       -10000
# 1768   Automatic 3-spd  1985       -10000
# 1770      Manual 6-spd  1995       -18500
# 1778      Manual 5-spd  1995       -13500
# 1781      Manual 5-spd  1995       -13500
# 1979   Automatic 3-spd  1985       -14000
# 1990   Automatic 3-spd  1985       -14000
# 2002      Manual 5-spd  1985       -14000
# 2807      Manual 5-spd  1996       -13500
# 2817      Manual 5-spd  1996       -15750
# 3208   Automatic 4-spd  1996        -1750
# 3629      Manual 5-spd  1997       -13500
# 3641      Manual 5-spd  1997       -15750
# 3706   Automatic 4-spd  1997       -13500
# 4036   Automatic 4-spd  1997        -1750
# 4443      Manual 6-spd  1998       -13500
# 4449      Manual 5-spd  1998       -13500
# 4544   Automatic 4-spd  1998         1250
# 5006   Automatic 4-spd  1998        -7000
# 5110   Automatic 4-spd  1998        -7000
# 5336      Manual 6-spd  1999       -13500
# 5339      Manual 5-spd  1999       -13500
# 5765   Automatic 4-spd  1999        -3250
# ...                ...   ...          ...
# 36455     Manual 4-spd  1985       -10000
# 36498  Automatic 4-spd  1992       -11750
# 36500  Automatic 4-spd  1992       -11750
# 36511     Manual 4-spd  1985       -10000
# 36617  Automatic 4-spd  1992       -11750
# 36618  Automatic 4-spd  1992       -11750
# 36666     Manual 4-spd  1985       -10000
# 36774  Automatic 4-spd  1992       -11750
# 36775  Automatic 4-spd  1992       -11750
# 36776  Automatic 4-spd  1992       -11750
# 36777  Automatic 4-spd  1992       -11750
# 36810  Automatic 4-spd  1992       -11750
# 36812  Automatic 4-spd  1992       -11750
# 36813  Automatic 4-spd  1992       -11750
# 36855  Automatic 4-spd  1992       -10250
# 36999  Automatic 4-spd  1992       -10000
# 37131     Manual 5-spd  1992       -10000
# 37137     Manual 5-spd  1992       -10000
# 37250  Automatic 4-spd  1992       -10000
# 37300  Automatic 3-spd  1985       -10000
# 37356     Manual 5-spd  1992       -10000
# 37431  Automatic 4-spd  1992       -10000
# 37448     Manual 5-spd  1993       -11750
# 37458  Automatic 3-spd  1993       -10250
# 37459     Manual 5-spd  1993       -13500
# 37475  Automatic 3-spd  1993       -18500
# 37615  Automatic 3-spd  1993       -10250
# 37672  Automatic 4-spd  1993       -11750
# 37673  Automatic 4-spd  1993       -11750
# 37827  Automatic 4-spd  1993       -11750
#
# [78266 rows x 39 columns]

# %%
outliers.index.value_counts()
# Out:
# 30143    16
# 27384    16
# 27366    16
# 28720    16
# 30141    16
# 29938    16
# 27703    16
# 29936    16
# 30974    16
# 26808    16
# 28592    16
# 25895    16
# 30972    16
# 29939    16
# 25955    16
# 29654    16
# 30557    16
# 28549    16
# 30975    16
# 25673    16
# 28560    16
# 26528    16
# 27227    16
# 29652    16
# 25684    16
# 28607    16
# 30973    16
# 25683    16
# 30142    16
# 30561    16
#          ..
# 26961     1
# 4382      1
# 34251     1
# 28946     1
# 19922     1
# 3546      1
# 20050     1
# 1627      1
# 34443     1
# 20114     1
# 11934     1
# 36554     1
# 34571     1
# 32532     1
# 34635     1
# 32596     1
# 3930      1
# 8088      1
# 2011      1
# 18453     1
# 20502     1
# 2077      1
# 32844     1
# 36942     1
# 14427     1
# 2141      1
# 4190      1
# 35021     1
# 18645     1
# 2049      1
# Length: 21407, dtype: int64

# %% [markdown]
# # Clean Text

# %% [markdown]
# 1. Pais vs Paris
# 2. Age=142
# 3. Avenue des Champs-Élysées vs Ave. des Champs-Élysées
# 4. Blvd. de l'Hôpital vs Blvd. de l'Hopital
# 5. Blvd. vs Blvd

# %%
df.trany.value_counts()
# Out:
# Automatic 4-spd                     11042
# Manual 5-spd                         8311
# Automatic 3-spd                      3151
# Automatic (S6)                       2638
# Manual 6-spd                         2429
# Automatic 5-spd                      2184
# Manual 4-spd                         1483
# Automatic 6-spd                      1432
# Automatic (S8)                        960
# Automatic (S5)                        824
# Automatic (variable gear ratios)      681
# Automatic 7-spd                       663
# Automatic (S7)                        261
# Auto(AM-S7)                           256
# Automatic 8-spd                       243
# Automatic (S4)                        233
# Auto(AM7)                             160
# Auto(AV-S6)                           145
# Auto(AM6)                             110
# Automatic (A1)                        109
# Auto(AM-S6)                            92
# Automatic 9-spd                        90
# Manual 3-spd                           77
# Manual 7-spd                           68
# Auto(AV-S7)                            63
# Automatic (S9)                         26
# Auto(AV-S8)                            26
# Manual 4-spd Doubled                   17
# Auto(AM5)                              12
# 0                                      11
# Automatic (AV-S6)                       9
# Auto(AM-S8)                             6
# Auto(AM8)                               5
# Automatic (A6)                          4
# Automatic (AV)                          4
# Manual(M7)                              3
# Auto (AV)                               2
# Auto(L3)                                2
# Automatic (AM5)                         2
# Auto(L4)                                2
# Auto(A1)                                1
# Automatic (AM6)                         1
# Auto (AV-S8)                            1
# Manual 5 spd                            1
# Auto (AV-S6)                            1
# Auto(AM-S9)                             1
# Automatic 6spd                          1
# Name: trany, dtype: int64

# %%
print(set(df.trany))
# Out:
# {'Automatic (S6)', 0, 'Auto(L4)', 'Auto(A1)', 'Automatic 7-spd', 'Automatic (S7)', 'Manual 4-spd Doubled', 'Automatic 4-spd', 'Manual 5 spd', 'Automatic (A6)', 'Manual 3-spd', 'Auto(AM6)', 'Auto(AM5)', 'Manual 5-spd', 'Automatic 6spd', 'Automatic (S9)', 'Automatic (A1)', 'Manual(M7)', 'Auto (AV-S6)', 'Automatic (AV)', 'Auto(AM-S8)', 'Auto (AV)', 'Manual 7-spd', 'Auto(AV-S6)', 'Auto(AM-S6)', 'Auto(L3)', 'Automatic 5-spd', 'Automatic (S4)', 'Auto(AM-S9)', 'Automatic 6-spd', 'Manual 4-spd', 'Automatic (S8)', 'Automatic (AM5)', 'Automatic (variable gear ratios)', 'Auto(AM7)', 'Manual 6-spd', 'Auto(AM8)', 'Auto(AM-S7)', 'Auto(AV-S7)', 'Automatic (AM6)', 'Automatic (S5)', 'Automatic 3-spd', 'Automatic 9-spd', 'Automatic (AV-S6)', 'Automatic 8-spd', 'Auto (AV-S8)', 'Auto(AV-S8)'}

# %%
df.trany=df.trany.str.replace('-','')
print(set(df.trany))
# Out:
# {'Automatic (S6)', nan, 'Auto(L4)', 'Automatic (AVS6)', 'Manual 6spd', 'Auto(A1)', 'Automatic 3spd', 'Automatic (S7)', 'Auto(AMS7)', 'Manual 5 spd', 'Automatic (A6)', 'Auto(AMS6)', 'Auto(AM6)', 'Auto(AM5)', 'Auto (AVS6)', 'Automatic 6spd', 'Automatic (S9)', 'Automatic (A1)', 'Automatic 4spd', 'Manual(M7)', 'Auto(AMS9)', 'Auto(AVS6)', 'Manual 3spd', 'Automatic (AV)', 'Automatic 7spd', 'Auto (AV)', 'Automatic 5spd', 'Manual 5spd', 'Auto(L3)', 'Auto (AVS8)', 'Automatic (S4)', 'Manual 7spd', 'Auto(AVS7)', 'Automatic (S8)', 'Auto(AVS8)', 'Automatic (AM5)', 'Automatic (variable gear ratios)', 'Auto(AM7)', 'Auto(AM8)', 'Manual 4spd Doubled', 'Automatic (AM6)', 'Automatic (S5)', 'Automatic 9spd', 'Automatic 8spd', 'Manual 4spd', 'Auto(AMS8)'}

# %%
df.trany=df.trany.str.replace('Automatic','Auto')
print(set(df.trany))
# Out:
# {nan, 'Auto(L4)', 'Manual 6spd', 'Auto(A1)', 'Auto(AMS7)', 'Manual 5 spd', 'Auto(AMS6)', 'Auto (A6)', 'Auto(AM6)', 'Auto(AM5)', 'Auto (AVS6)', 'Manual(M7)', 'Auto(AMS9)', 'Auto 9spd', 'Auto(AVS6)', 'Manual 3spd', 'Auto 6spd', 'Auto 8spd', 'Auto (AM5)', 'Auto (AV)', 'Auto (S9)', 'Manual 5spd', 'Auto(L3)', 'Auto (S5)', 'Auto (variable gear ratios)', 'Auto (AM6)', 'Auto (AVS8)', 'Auto 5spd', 'Auto 4spd', 'Manual 7spd', 'Auto (S6)', 'Auto(AVS7)', 'Auto(AVS8)', 'Auto (S8)', 'Auto(AM7)', 'Auto (A1)', 'Auto(AM8)', 'Auto 7spd', 'Auto 3spd', 'Manual 4spd Doubled', 'Auto (S4)', 'Auto (S7)', 'Manual 4spd', 'Auto(AMS8)'}

# %%
df.trany=df.trany.str.replace('Auto\(','Auto ')
df.trany=df.trany.str.replace('Manual\(','Manual ')
df.trany=df.trany.str.replace('\(','')
df.trany=df.trany.str.replace('\)','')
print(set(df.trany))
# Out:
# {nan, 'Auto S8', 'Manual M7', 'Manual 6spd', 'Manual 5 spd', 'Auto S7', 'Auto S4', 'Auto AV', 'Auto AVS7', 'Auto S9', 'Auto AVS8', 'Auto A6', 'Auto S6', 'Auto A1', 'Auto AMS7', 'Manual 3spd', 'Auto 9spd', 'Auto 6spd', 'Auto 8spd', 'Auto AM8', 'Manual 5spd', 'Auto L3', 'Auto AVS6', 'Auto 5spd', 'Auto AM6', 'Auto 4spd', 'Manual 7spd', 'Auto variable gear ratios', 'Auto L4', 'Auto AMS8', 'Auto S5', 'Auto AMS9', 'Auto 7spd', 'Auto 3spd', 'Manual 4spd Doubled', 'Auto AM7', 'Auto AM5', 'Auto AMS6', 'Manual 4spd'}

# %%
df.trany.value_counts()
# Out:
# Auto 4spd                    11042
# Manual 5spd                   8311
# Auto 3spd                     3151
# Auto S6                       2638
# Manual 6spd                   2429
# Auto 5spd                     2184
# Manual 4spd                   1483
# Auto 6spd                     1433
# Auto S8                        960
# Auto S5                        824
# Auto variable gear ratios      681
# Auto 7spd                      663
# Auto S7                        261
# Auto AMS7                      256
# Auto 8spd                      243
# Auto S4                        233
# Auto AM7                       160
# Auto AVS6                      155
# Auto AM6                       111
# Auto A1                        110
# Auto AMS6                       92
# Auto 9spd                       90
# Manual 3spd                     77
# Manual 7spd                     68
# Auto AVS7                       63
# Auto AVS8                       27
# Auto S9                         26
# Manual 4spd Doubled             17
# Auto AM5                        14
# Auto AV                          6
# Auto AMS8                        6
# Auto AM8                         5
# Auto A6                          4
# Manual M7                        3
# Auto L4                          2
# Auto L3                          2
# Manual 5 spd                     1
# Auto AMS9                        1
# Name: trany, dtype: int64

# %% [markdown]
# # Duplicates

# %%
before=len(df)
df=df.drop_duplicates()
after=len(df)
print('Number of duplicates dropped:', str(before-after))
# Out:
# Number of duplicates dropped: 0

# %%
select_columns = ['make', 'model', 'year', 'displ', 'cylinders', 
                  'trany', 'drive', 'VClass','fuelType','barrels08', 
                  'city08', 'highway08', 'comb08', 'co2TailpipeGpm', 'fuelCost08']

df=df[select_columns].drop_duplicates()
after=len(df)
print('Number of duplicates dropped:', str(before-after))
# Out:
# Number of duplicates dropped: 885

# %%
df
# Out:
#               make                model  year  displ  cylinders        trany  \
# 0       Alfa Romeo   Spider Veloce 2000  1985    2.0        4.0  Manual 5spd
# 1          Ferrari           Testarossa  1985    4.9       12.0  Manual 5spd
# 2            Dodge              Charger  1985    2.2        4.0  Manual 5spd
# 3            Dodge  B150/B250 Wagon 2WD  1985    5.2        8.0    Auto 3spd
# 4           Subaru     Legacy AWD Turbo  1993    2.2        4.0  Manual 5spd
# 5           Subaru               Loyale  1993    1.8        4.0    Auto 3spd
# 6           Subaru               Loyale  1993    1.8        4.0  Manual 5spd
# 7           Toyota              Corolla  1993    1.6        4.0    Auto 3spd
# 8           Toyota              Corolla  1993    1.6        4.0  Manual 5spd
# 9           Toyota              Corolla  1993    1.8        4.0    Auto 4spd
# 10          Toyota              Corolla  1993    1.8        4.0  Manual 5spd
# 11      Volkswagen       Golf III / GTI  1993    2.0        4.0    Auto 4spd
# 12      Volkswagen       Golf III / GTI  1993    2.0        4.0  Manual 5spd
# 13      Volkswagen            Jetta III  1993    2.0        4.0    Auto 4spd
# 14           Dodge  B150/B250 Wagon 2WD  1985    5.2        8.0    Auto 3spd
# 15      Volkswagen            Jetta III  1993    2.0        4.0  Manual 5spd
# 16           Volvo                  240  1993    2.3        4.0    Auto 4spd
# 17           Volvo                  240  1993    2.3        4.0  Manual 5spd
# 18            Audi                  100  1993    2.8        6.0    Auto 4spd
# 19            Audi                  100  1993    2.8        6.0  Manual 5spd
# 20             BMW                 740i  1993    4.0        8.0    Auto 5spd
# 21             BMW                740il  1993    4.0        8.0    Auto 5spd
# 22             BMW                750il  1993    5.0       12.0    Auto 4spd
# 23           Buick              Century  1993    2.2        4.0    Auto 3spd
# 24           Buick              Century  1993    3.3        6.0    Auto 3spd
# 25           Dodge  B150/B250 Wagon 2WD  1985    5.2        8.0  Manual 4spd
# 26           Buick              Century  1993    3.3        6.0    Auto 4spd
# 27           Buick                Regal  1993    3.1        6.0    Auto 3spd
# 28           Buick                Regal  1993    3.1        6.0    Auto 4spd
# 29           Buick                Regal  1993    3.8        6.0    Auto 4spd
# ...            ...                  ...   ...    ...        ...          ...
# 37813     Plymouth      Sundance/Duster  1993    2.2        4.0  Manual 5spd
# 37814     Plymouth      Sundance/Duster  1993    2.5        4.0    Auto 3spd
# 37815     Plymouth      Sundance/Duster  1993    2.5        4.0  Manual 5spd
# 37816     Plymouth      Sundance/Duster  1993    3.0        6.0    Auto 4spd
# 37817     Plymouth      Sundance/Duster  1993    3.0        6.0  Manual 5spd
# 37818      Pontiac             Grand Am  1993    2.3        4.0    Auto 3spd
# 37819      Pontiac             Grand Am  1993    2.3        4.0    Auto 3spd
# 37820      Pontiac             Grand Am  1993    2.3        4.0  Manual 5spd
# 37821        Dodge  B150/B250 Wagon 2WD  1985    3.7        6.0  Manual 4spd
# 37822      Pontiac             Grand Am  1993    2.3        4.0  Manual 5spd
# 37823      Pontiac             Grand Am  1993    3.3        6.0    Auto 3spd
# 37824      Pontiac               Lemans  1993    1.6        4.0    Auto 3spd
# 37825      Pontiac               Lemans  1993    1.6        4.0  Manual 4spd
# 37826      Pontiac               Lemans  1993    1.6        4.0  Manual 5spd
# 37827  Rolls-Royce        Continental R  1993    6.8        8.0    Auto 4spd
# 37828         Saab                  900  1993    2.0        4.0    Auto 3spd
# 37829         Saab                  900  1993    2.0        4.0  Manual 5spd
# 37830         Saab                  900  1993    2.0        4.0  Manual 5spd
# 37831         Saab                  900  1993    2.1        4.0    Auto 3spd
# 37832        Dodge  B150/B250 Wagon 2WD  1985    5.2        8.0    Auto 3spd
# 37833         Saab                  900  1993    2.1        4.0  Manual 5spd
# 37834       Saturn                   SL  1993    1.9        4.0    Auto 4spd
# 37835       Saturn                   SL  1993    1.9        4.0    Auto 4spd
# 37836       Saturn                   SL  1993    1.9        4.0  Manual 5spd
# 37837       Saturn                   SL  1993    1.9        4.0  Manual 5spd
# 37838       Subaru               Legacy  1993    2.2        4.0    Auto 4spd
# 37839       Subaru               Legacy  1993    2.2        4.0  Manual 5spd
# 37840       Subaru           Legacy AWD  1993    2.2        4.0    Auto 4spd
# 37841       Subaru           Legacy AWD  1993    2.2        4.0  Manual 5spd
# 37842       Subaru     Legacy AWD Turbo  1993    2.2        4.0    Auto 4spd
#
#                             drive           VClass fuelType  barrels08  \
# 0                Rear-Wheel Drive      Two Seaters  Regular  15.695714
# 1                Rear-Wheel Drive      Two Seaters  Regular  29.964545
# 2               Front-Wheel Drive  Subcompact Cars  Regular  12.207778
# 3                Rear-Wheel Drive             Vans  Regular  29.964545
# 4      4-Wheel or All-Wheel Drive     Compact Cars  Premium  17.347895
# 5               Front-Wheel Drive     Compact Cars  Regular  14.982273
# 6               Front-Wheel Drive     Compact Cars  Regular  13.184400
# 7               Front-Wheel Drive     Compact Cars  Regular  13.733750
# 8               Front-Wheel Drive     Compact Cars  Regular  12.677308
# 9               Front-Wheel Drive     Compact Cars  Regular  13.184400
# 10              Front-Wheel Drive     Compact Cars  Regular  12.677308
# 11              Front-Wheel Drive     Compact Cars  Regular  15.695714
# 12              Front-Wheel Drive     Compact Cars  Regular  13.733750
# 13              Front-Wheel Drive     Compact Cars  Regular  15.695714
# 14               Rear-Wheel Drive             Vans  Regular  25.354615
# 15              Front-Wheel Drive     Compact Cars  Regular  14.330870
# 16               Rear-Wheel Drive     Compact Cars  Regular  16.480500
# 17               Rear-Wheel Drive     Compact Cars  Regular  15.695714
# 18              Front-Wheel Drive     Midsize Cars  Premium  17.347895
# 19              Front-Wheel Drive     Midsize Cars  Premium  17.347895
# 20               Rear-Wheel Drive     Midsize Cars  Premium  20.600625
# 21               Rear-Wheel Drive     Midsize Cars  Premium  20.600625
# 22               Rear-Wheel Drive     Midsize Cars  Regular  25.354615
# 23              Front-Wheel Drive     Midsize Cars  Regular  14.330870
# 24              Front-Wheel Drive     Midsize Cars  Regular  17.347895
# 25               Rear-Wheel Drive             Vans  Regular  25.354615
# 26              Front-Wheel Drive     Midsize Cars  Regular  15.695714
# 27              Front-Wheel Drive     Midsize Cars  Regular  16.480500
# 28              Front-Wheel Drive     Midsize Cars  Regular  16.480500
# 29              Front-Wheel Drive     Midsize Cars  Regular  16.480500
# ...                           ...              ...      ...        ...
# 37813           Front-Wheel Drive     Compact Cars  Regular  12.677308
# 37814           Front-Wheel Drive     Compact Cars  Regular  14.330870
# 37815           Front-Wheel Drive     Compact Cars  Regular  13.184400
# 37816           Front-Wheel Drive     Compact Cars  Regular  15.695714
# 37817           Front-Wheel Drive     Compact Cars  Regular  16.480500
# 37818           Front-Wheel Drive     Compact Cars  Regular  14.982273
# 37819           Front-Wheel Drive     Compact Cars  Regular  14.330870
# 37820           Front-Wheel Drive     Compact Cars  Regular  13.733750
# 37821            Rear-Wheel Drive             Vans  Regular  21.974000
# 37822           Front-Wheel Drive     Compact Cars  Premium  15.695714
# 37823           Front-Wheel Drive     Compact Cars  Regular  15.695714
# 37824           Front-Wheel Drive     Compact Cars  Regular  13.184400
# 37825           Front-Wheel Drive     Compact Cars  Regular  11.771786
# 37826           Front-Wheel Drive     Compact Cars  Regular  10.987000
# 37827            Rear-Wheel Drive     Compact Cars  Premium  29.964545
# 37828           Front-Wheel Drive     Compact Cars  Regular  18.311667
# 37829           Front-Wheel Drive     Compact Cars  Regular  15.695714
# 37830           Front-Wheel Drive     Compact Cars  Premium  15.695714
# 37831           Front-Wheel Drive     Compact Cars  Regular  18.311667
# 37832            Rear-Wheel Drive             Vans  Regular  27.467500
# 37833           Front-Wheel Drive     Compact Cars  Regular  16.480500
# 37834           Front-Wheel Drive     Compact Cars  Regular  12.677308
# 37835           Front-Wheel Drive     Compact Cars  Regular  13.733750
# 37836           Front-Wheel Drive     Compact Cars  Regular  11.771786
# 37837           Front-Wheel Drive     Compact Cars  Regular  13.184400
# 37838           Front-Wheel Drive     Compact Cars  Regular  14.982273
# 37839           Front-Wheel Drive     Compact Cars  Regular  14.330870
# 37840  4-Wheel or All-Wheel Drive     Compact Cars  Regular  15.695714
# 37841  4-Wheel or All-Wheel Drive     Compact Cars  Regular  15.695714
# 37842  4-Wheel or All-Wheel Drive     Compact Cars  Premium  18.311667
#
#        city08  highway08  comb08  co2TailpipeGpm  fuelCost08
# 0          19         25      21      423.190476        1600
# 1           9         14      11      807.909091        3050
# 2          23         33      27      329.148148        1250
# 3          10         12      11      807.909091        3050
# 4          17         23      19      467.736842        2150
# 5          21         24      22      403.954545        1500
# 6          22         29      25      355.480000        1350
# 7          23         26      24      370.291667        1400
# 8          23         31      26      341.807692        1300
# 9          23         30      25      355.480000        1350
# 10         23         30      26      341.807692        1300
# 11         18         26      21      423.190476        1600
# 12         21         29      24      370.291667        1400
# 13         18         26      21      423.190476        1600
# 14         12         15      13      683.615385        2550
# 15         20         28      23      386.391304        1450
# 16         18         23      20      444.350000        1650
# 17         19         26      21      423.190476        1600
# 18         17         22      19      467.736842        2150
# 19         17         24      19      467.736842        2150
# 20         14         20      16      555.437500        2550
# 21         14         20      16      555.437500        2550
# 22         11         17      13      683.615385        2550
# 23         21         28      23      386.391304        1450
# 24         17         24      19      467.736842        1750
# 25         11         17      13      683.615385        2550
# 26         18         26      21      423.190476        1600
# 27         17         25      20      444.350000        1650
# 28         17         27      20      444.350000        1650
# 29         17         26      20      444.350000        1650
# ...       ...        ...     ...             ...         ...
# 37813      23         29      26      341.807692        1300
# 37814      21         26      23      386.391304        1450
# 37815      22         29      25      355.480000        1350
# 37816      18         26      21      423.190476        1600
# 37817      17         26      20      444.350000        1650
# 37818      19         26      22      403.954545        1500
# 37819      19         29      23      386.391304        1450
# 37820      21         32      24      370.291667        1400
# 37821      14         17      15      592.466667        2200
# 37822      18         27      21      423.190476        1950
# 37823      18         26      21      423.190476        1600
# 37824      23         29      25      355.480000        1350
# 37825      24         34      28      317.392857        1200
# 37826      26         37      30      296.233333        1100
# 37827      10         15      11      807.909091        3700
# 37828      17         21      18      493.722222        1850
# 37829      18         26      21      423.190476        1600
# 37830      18         25      21      423.190476        1950
# 37831      16         20      18      493.722222        1850
# 37832      11         13      12      740.583333        2800
# 37833      18         24      20      444.350000        1650
# 37834      23         33      26      341.807692        1300
# 37835      21         30      24      370.291667        1400
# 37836      24         33      28      317.392857        1200
# 37837      21         32      25      355.480000        1350
# 37838      19         26      22      403.954545        1500
# 37839      20         28      23      386.391304        1450
# 37840      18         24      21      423.190476        1600
# 37841      18         24      21      423.190476        1600
# 37842      16         21      18      493.722222        2250
#
# [36958 rows x 15 columns]
