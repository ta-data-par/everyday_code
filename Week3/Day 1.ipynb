# %%
import json
import requests
import pandas as pd
from pandas.io.json import json_normalize

# %%
url=''

https://
www.zalando.fr
/api/catalog/
articles?categories=promo-enfant&limit=84&offset=84&sort=sale


5xx

# %%
response=requests.get(url)
results=response.json()

flat_data=json_normalize(results)
flat_data.articles[0]

flat_data1=json_normalize(flat_data.articles[0])
flat_data1=flat_data1.set_index('sku')
flat_data1.brand_name.value_counts()
# Out:
# Nike Sportswear        20
# adidas Originals       11
# Nike Performance        7
# Converse                5
# Friboo                  5
# Puma                    3
# Name it                 3
# Tommy Hilfiger          3
# Polo Ralph Lauren       3
# Levi's®                 2
# Benetton                2
# adidas Performance      2
# Lacoste                 2
# Vans                    2
# New Era                 1
# OshKosh                 1
# mothercare              1
# Abercrombie & Fitch     1
# Carter's                1
# Birkenstock             1
# Champion                1
# Reebok Classic          1
# Outfit Kids             1
# Petit Bateau            1
# Geox                    1
# Nike SB                 1
# New Balance             1
# Jack & Jones Junior     1
# Name: brand_name, dtype: int64

# %%
response=requests.get('https://jsonplaceholder.typicode.com/todos')
results=response.json()
results
# Out:
# [{'userId': 1, 'id': 1, 'title': 'delectus aut autem', 'completed': False},
#  {'userId': 1,
#   'id': 2,
#   'title': 'quis ut nam facilis et officia qui',
#   'completed': False},
#  {'userId': 1, 'id': 3, 'title': 'fugiat veniam minus', 'completed': False},
#  {'userId': 1, 'id': 4, 'title': 'et porro tempora', 'completed': True},
#  {'userId': 1,
#   'id': 5,
#   'title': 'laboriosam mollitia et enim quasi adipisci quia provident illum',
#   'completed': False},
#  {'userId': 1,
#   'id': 6,
#   'title': 'qui ullam ratione quibusdam voluptatem quia omnis',
#   'completed': False},
#  {'userId': 1,
#   'id': 7,
#   'title': 'illo expedita consequatur quia in',
#   'completed': False},
#  {'userId': 1,
#   'id': 8,
#   'title': 'quo adipisci enim quam ut ab',
#   'completed': True},
#  {'userId': 1,
#   'id': 9,
#   'title': 'molestiae perspiciatis ipsa',
#   'completed': False},
#  {'userId': 1,
#   'id': 10,
#   'title': 'illo est ratione doloremque quia maiores aut',
# ...

# %%
data=pd.DataFrame(results)
data
# Out:
#      completed   id                                              title  userId
# 0        False    1                                 delectus aut autem       1
# 1        False    2                 quis ut nam facilis et officia qui       1
# 2        False    3                                fugiat veniam minus       1
# 3         True    4                                   et porro tempora       1
# 4        False    5  laboriosam mollitia et enim quasi adipisci qui...       1
# 5        False    6  qui ullam ratione quibusdam voluptatem quia omnis       1
# 6        False    7                  illo expedita consequatur quia in       1
# 7         True    8                       quo adipisci enim quam ut ab       1
# 8        False    9                        molestiae perspiciatis ipsa       1
# 9         True   10       illo est ratione doloremque quia maiores aut       1
# 10        True   11                        vero rerum temporibus dolor       1
# ...

# %%
response=requests.get('https://api.github.com/events')
results=response.json()
results
# Out:
# [{'id': '9702777537',
#   'type': 'PushEvent',
#   'actor': {'id': 36771260,
#    'login': 'pavankumarDVG',
#    'display_login': 'pavankumarDVG',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/pavankumarDVG',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/36771260?'},
#   'repo': {'id': 188782577,
#    'name': 'pavankumarDVG/Trail',
#    'url': 'https://api.github.com/repos/pavankumarDVG/Trail'},
#   'payload': {'push_id': 3650409968,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/master',
#    'head': 'dc41b84015d05f4e1c597e12fac1934deb9c8045',
#    'before': 'ab647dac6a4c6b2e415b725490c60469331b6b66',
#    'commits': [{'sha': 'dc41b84015d05f4e1c597e12fac1934deb9c8045',
#      'author': {'email': '36771260+pavankumarDVG@users.noreply.github.com',
#       'name': 'pavankumarDVG'},
#      'message': 'Create publications.md',
#      'distinct': True,
# ...

# %%
data=pd.DataFrame(results)
data
# Out:
#                                                 actor            created_at  \
# 0   {'id': 36771260, 'login': 'pavankumarDVG', 'di...  2019-05-27T09:35:54Z
# 1   {'id': 41335991, 'login': 'charlesStOlive', 'd...  2019-05-27T09:35:54Z
# 2   {'id': 18191964, 'login': 'NashMiao', 'display...  2019-05-27T09:35:54Z
# 3   {'id': 3671457, 'login': 'onemanking', 'displa...  2019-05-27T09:35:54Z
# 4   {'id': 429981, 'login': 'whiskeysierra', 'disp...  2019-05-27T09:35:54Z
# 5   {'id': 7146779, 'login': 'iqyeah', 'display_lo...  2019-05-27T09:35:54Z
# 6   {'id': 2284279, 'login': 'onmyway133', 'displa...  2019-05-27T09:35:54Z
# 7   {'id': 3205414, 'login': 'nbkr', 'display_logi...  2019-05-27T09:35:54Z
# 8   {'id': 8470820, 'login': 'SeaHOH', 'display_lo...  2019-05-27T09:35:54Z
# 9   {'id': 2708211, 'login': 'lossir', 'display_lo...  2019-05-27T09:35:54Z
# 10  {'id': 7165771, 'login': 'pedrobaeza', 'displa...  2019-05-27T09:35:54Z
# ...

# %%
def flatten(data, col_list):
    for column in col_list:
        flattened = pd.DataFrame(dict(data[column])).transpose()
        columns = [str(col) for col in flattened.columns]
        flattened.columns = [column + '_' + colname for colname in columns]
        data = pd.concat([data, flattened], axis=1)
        data = data.drop(column, axis=1)
    return data

flat=flatten(data,['actor','org','payload','repo'])
flat.head()
# Out:
#              created_at          id  public               type  \
# 0  2019-05-27T09:35:54Z  9702777537    True          PushEvent
# 1  2019-05-27T09:35:54Z  9702777536    True          PushEvent
# 2  2019-05-27T09:35:54Z  9702777528    True          PushEvent
# 3  2019-05-27T09:35:54Z  9702777529    True          ForkEvent
# 4  2019-05-27T09:35:54Z  9702777521    True  IssueCommentEvent
#
#                                     actor_avatar_url actor_display_login  \
# 0  https://avatars.githubusercontent.com/u/36771260?       pavankumarDVG
# 1  https://avatars.githubusercontent.com/u/41335991?      charlesStOlive
# 2  https://avatars.githubusercontent.com/u/18191964?            NashMiao
# 3   https://avatars.githubusercontent.com/u/3671457?          onemanking
# 4    https://avatars.githubusercontent.com/u/429981?       whiskeysierra
#
#   actor_gravatar_id  actor_id     actor_login  \
# 0                    36771260   pavankumarDVG
# 1                    41335991  charlesStOlive
# ...

# %%
flatt=json_normalize(results)
flatt
# Out:
#                                      actor.avatar_url actor.display_login  \
# 0   https://avatars.githubusercontent.com/u/36771260?       pavankumarDVG
# 1   https://avatars.githubusercontent.com/u/41335991?      charlesStOlive
# 2   https://avatars.githubusercontent.com/u/18191964?            NashMiao
# 3    https://avatars.githubusercontent.com/u/3671457?          onemanking
# 4     https://avatars.githubusercontent.com/u/429981?       whiskeysierra
# 5    https://avatars.githubusercontent.com/u/7146779?              iqyeah
# 6    https://avatars.githubusercontent.com/u/2284279?          onmyway133
# 7    https://avatars.githubusercontent.com/u/3205414?                nbkr
# 8    https://avatars.githubusercontent.com/u/8470820?              SeaHOH
# 9    https://avatars.githubusercontent.com/u/2708211?              lossir
# 10   https://avatars.githubusercontent.com/u/7165771?          pedrobaeza
# 11  https://avatars.githubusercontent.com/u/48905059?        M0ng0lFalcon
# ...

# %%
response=requests.get(url)
results=response.json()

flat_data=json_normalize(results)
flat_data
# Out:
#                                             articles  articlesToShow  \
# 0  [{'sku': 'NI116D040-C11', 'name': 'AIR MAX AXI...              84
#
#                                          breadcrumbs carouselTeaser  \
# 0  [{'items': [{'label': 'Enfant', 'url_key': 'en...           None
#
#                                         categoryTree collection  \
# 0  [{'label': 'Promotions', 'id': '9574', 'url_ke...       None
#
#   contentPositions.entry-point-teasers  contentPositions.in-cat-carousel  \
# 0                      [7, 14, 20, 26]                                 9
#
#    contentPositions.in-cat-carousel-fullwidth  \
# 0                                           8
#
#    contentPositions.in-cat-carousel-mobile  ...  variants.inlineNavbar  \
# 0                                        6  ...                  False
#
#    variants.mobileLightFilters variants.myBrandsFilter  \
# 0                        False                    True
#
# ...
